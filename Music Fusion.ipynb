# %% [markdown]
# ## Pré-processamento
#
# Na fase de criação do dataset uma parte do pré-processamento já foi feita, foi o passo de transformar todas as letras em minúsculas. Na fase atual, inicialmente, tivemos a ideia de remover as stopwords que englobam conectivos como conjunções (e, como, ou, ...). Caso fossem removidas os versos poderiam ficar sem muito significado.
#
# Referências:
#  - https://keras.io/examples/lstm_text_generation/
#  - https://towardsdatascience.com/ai-generates-taylor-swifts-song-lyrics-6fd92a03ef7e

# %%
# Bibliotecas utilizadas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from keras.models import Sequential
from keras.layers import LSTM, Activation, Flatten, Dropout, Dense, Embedding, TimeDistributed, GRU
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
import re
import sys

# %matplotlib inline

# %%
# Importação dos dados
dataset = pd.read_csv('musics.csv', encoding = "utf-8")
dataset
# Out:
#                   artist                                              music  \
# 0                 Djavan  valei-me, deus!\né o fim do nosso amor\nperdoa...
# 1           Gilberto Gil  aiaiá, kiriê \nkiriê, iaiá \n\na refavela \nre...
# 2         Caetano Veloso  eu sou o vento que lança a areia do saara\nsob...
# 3           Cássia Eller  é uma índia com colar\na tarde linda que não q...
# 4            Elis Regina  não quero lhe falar meu grande amor \ndas cois...
# 5        Geraldo Azevedo  se você vier pro que der e vier comigo\neu lhe...
# 6    Adriana Calcanhotto  rasgue as minhas cartas\ne não me procure mais...
# 7          João Gilberto  vai minha tristeza e diz a ela que\nsem ela nã...
# 8          Chico Buarque  não se afobe, não\nque nada é pra já \no amor ...
# 9         Ney Matogrosso  tudo de bom que você me fizer\nfaz minha rima ...
# 10             Gal Costa  se tem luar no céu\nretira o véu e faz chover ...
# 11          Gilberto Gil  se eu quiser falar com deus\ngilberto gil\n198...
# 12          Gilberto Gil  aquele abraço\n\ngilberto gil\n1969\n\no rio d...
# 13             Gal Costa  o que é que há?\no que é que tá se passando co...
# 14           Tribalistas  vem pra minha aula que hoje a nossa escola\nva...
# 15         Chico Buarque  vou voltar\nsei que ainda vou voltar\npara o m...
# 16     Milton Nascimento  já falei tantas vezes\ndo verde dos teus olhos...
# 17                Lenine  daqui desse momento\ndo meu olhar pra fora\no ...
# 18           Lulu Santos  eu gosto tanto de você\nque até prefiro escond...
# 19            Nando Reis  como vai você?\neu preciso saber da sua vida\n...
# 20           Elza Soares  disparo contra o sol\nsou forte, sou por acaso...
# 21        Maria Bethânia  quando você me deixou, meu bem\nme disse pra s...
# 22              Toquinho  o homem que diz "dou" não dá, porque quem dá m...
# 23            Zé Ramalho  há um brilho de faca\nonde o amor vier\ne ning...
# 24             Lô Borges  da janela lateral do quarto de dormir\nvejo um...
# 25         Chico Buarque  amou daquela vez como se fosse a última\nbeijo...
# 26       Teresa Cristina  linda\nte sinto mais bela\nte fico na espera\n...
# 27             Gal Costa  dueto com luís melodia\n\ntente passar pelo qu...
# 28           Tribalistas  se um dia eu te encontrar\ndo jeito que sonhei...
# 29               Cartola  deixe-me ir, preciso andar\nvou por aí a procu...
# 30  Antônio Carlos Jobim  é pau, é pedra, é o fim do caminho\né um resto...
# 31          Zeca Baleiro  eu não sei dizer\no que quer dizer\no que vou ...
# 32         Alceu Valença  na bruma leve das paixões que vêm de dentro\nt...
# 33                Djavan  eu não digo que não\nela é bela e fera\nmas nã...
# 34                Lenine  mesmo quando tudo pede um pouco mais de calma\...
# 35           Raul Seixas  eu prefiro ser\nessa metamorfose ambulante\neu...
# 36         Patricia Marx  os seus olhos são espelhos d'água\nbrilhando v...
# 37        Caetano Veloso  onde queres revólver, sou coqueiro\nonde quere...
# 38               Cartola  ainda é cedo, amor\nmal começaste a conhecer a...
# 39          Marisa Monte  penso em ficar quieto um pouquinho\nlá no meio...
# 40                Cazuza  amor da minha vida\ndaqui até a eternidade\nno...
# 41            Maria Gadú  sai de si \nvem curar teu mal\nte transbordo e...
# 42          Ana Carolina  eu e você\nnão é assim tão complicado\nnão é d...
# 43              Toquinho  numa folha qualquer eu desenho um sol amarelo\...
# 44          Marisa Monte  depois de sonhar tantos anos\nde fazer tantos ...
# 45            Maria Rita  perfumei o corredor,\nperfumei  o elevador\npr...
# 46             Ivan Lins  lembra de mim \ndos beijos que escrevi nos mur...
# 47         Novos Baianos  chegou a hora dessa gente bronzeada mostrar se...
# 48              Tim Maia  uh! uh! uh! que beleza!\nuh! uh! uh! que belez...
# 49                Djavan  pai e mãe\nouro de mina\ncoração\ndesejo e sin...
# 50         Novos Baianos  enquanto eu corria, assim eu ia\neu ia lhe cha...
# 51            Zé Ramalho  eu desço dessa solidão\nespalho coisas sobre u...
# 52        Maria Bethânia  samba da benção\n(vinícius de moraes)\n\né mel...
# 53              Rita Lee  lança menina, lança todo este perfume\ndesbara...
# 54         Chico Buarque  o que será que será\nque andam suspirando pela...
# 55         Jorge Ben Jor  oba lá vem ela estou de olho nela\nnão me impo...
# 56            João Bosco  caía a tarde feito um viaduto\ne um bêbado tra...
#
#                                            track
# 0                                    Flor de Lis
# 1                                       Refavela
# 2                            Reconvexo - Ao Vivo
# 3                            Relicário - Ao Vivo
# 4                               Como Nossos Pais
# 5             Dia Branco - Ao Vivo | Bonus Track
# 6                           Devolva-Me (Ao Vivo)
# 7                               Chega de Saudade
# 8                                Futuros Amantes
# 9                                          Sorte
# 10                      Chuva de Prata - Ao Vivo
# 11                   Se Eu Quiser Falar Com Deus
# 12                                 Aquele Abraço
# 13                                O Que É Que Há
# 14                          Carnavália - Ao Vivo
# 15                               Sabiá - Ao Vivo
# 16                            A Festa - Acústico
# 17                É O Que Me Interessa - Ao Vivo
# 18                       Apenas Mais uma de Amor
# 19                                 Como Vai Você
# 20                              O Tempo Não Para
# 21                               Olhos Nos Olhos
# 22                              Canto de Ossanha
# 23        Entre a Serpente e a Estrela - Ao Vivo
# 24                  Paisagem da Janela - Ao Vivo
# 25                                    Construção
# 26                  Corra e Olhe o Céu - Ao Vivo
# 27                        Pérola Negra - Ao Vivo
# 28                                       Aliança
# 29                          Preciso Me Encontrar
# 30                                Águas De Março
# 31                                         Lenha
# 32                          Anunciação - Ao Vivo
# 33                               Não é um Bolero
# 34                                     Paciência
# 35                         Metamorfose ambulante
# 36                               Espelhos D'água
# 37                                    O Quereres
# 38                           O Mundo É Um Moinho
# 39                         Nu Com A Minha Música
# 40                                 Exagerado 3.0
# 41                                      Encontro
# 42  Quem de nós Dois (La Mia Storia Tra Le Dita)
# 43                                      Aquarela
# 44                                        Depois
# 45                                   Tá perdoado
# 46                                 Lembra de Mim
# 47                               Brasil Pandeiro
# 48                                    Que Beleza
# 49                                          Sina
# 50                                Preta Pretinha
# 51                                   Chão de Giz
# 52                               Samba da Bênção
# 53                                 Lança Perfume
# 54                  O Que Será (A Flor Da Terra)
# 55                               Oba, Lá Vem Ela
# 56                     O Bêbado e a Equilibrista

# %% [markdown]
# ## Wordcloud
#
# Visualização das palavras que mais se repetem do dataset importado. É claro que conjunções e pronomes são mais utilizados, talvez até poluam o dataset, mas sem estas palavras o sentido dos versos/frases estará comprometido e por isso não serão removidas.

# %%
musics = ''.join(dataset['music'])
wordcloud = WordCloud(max_font_size=100, max_words=200, background_color="black").generate(musics)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Vetorização dos textos
#
#
# Referências:
# - https://stackabuse.com/python-for-nlp-deep-learning-text-generation-with-keras/
#
# Mapeando caracteres para char e chars para caracteres.

# %%
chars = sorted(list(set(musics)))
int_chars = dict((i, c) for i, c in enumerate(chars))
chars_int = dict((i, c) for c, i in enumerate(chars))

# %%
n_chars = len(musics)
n_vocab = len(chars)

# %%
seq_len = 100
data_X = []
data_y = []
for i in range(0, n_chars - seq_len, 1):
    seq_in  = musics[i:i+seq_len]
    seq_out = musics[i + seq_len]
    data_X.append([chars_int[char] for char in seq_in])
    data_y.append(chars_int[seq_out])
n_patterns = len(data_X)

# %%
X = np.reshape(data_X, (n_patterns, seq_len, 1))
X = X/float(n_vocab)
#Hot encode
y = np_utils.to_categorical(data_y)

# %% [markdown]
# # Construção do modelo
# Construindo um modelo utilizado o mecanismo "Gated recurrent units"(GRU).

# %%
GRU_layer_num = 4;
layer_size = [200, 200, 200, 200]

model = Sequential()
model.add(GRU(layer_size[0], input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))

for i in range(1, GRU_layer_num):
    model.add(GRU(layer_size[i], return_sequences=True))
    model.add(Dropout(0.2))

# %%
# Adição da função de ativação
model.add(Flatten())
model.add(Dense(y.shape[1]))
model.add(Activation('softmax'))
model.compile(loss= 'categorical_crossentropy', optimizer = 'adam')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_9 (GRU)                  (None, 100, 200)          121200
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 100, 200)          0
# _________________________________________________________________
# gru_10 (GRU)                 (None, 100, 200)          240600
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100, 200)          0
# _________________________________________________________________
# gru_11 (GRU)                 (None, 100, 200)          240600
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 100, 200)          0
# _________________________________________________________________
# gru_12 (GRU)                 (None, 100, 200)          240600
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 100, 200)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 20000)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 63)                1260063
# _________________________________________________________________
# activation_3 (Activation)    (None, 63)                0
# =================================================================
# Total params: 2,103,063
# Trainable params: 2,103,063
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_name = 'Weights-GRU-improvement-{epoch:03d}-{loss:.5f}-bigger.hdf5'
checkpoint = ModelCheckpoint(checkpoint_name, monitor='loss', verbose=1, save_best_only = True, mode = 'min')
callbacks_list = [checkpoint]

# %%
# Treinamento

model_params = {
    'epochs': 10,
    'batch_size': 128,
    'callbacks': callbacks_list,
    'verbose': 1,
    'validation_split': 0.8,
    'validation_data': None,
    'shuffle': True,
    'initial_epoch': 0,
    'steps_per_epoch': None,
    'validation_steps': None
    }

model.fit(X, 
          y,
          epochs = model_params['epochs'],
          batch_size= model_params['batch_size'],
          callbacks = model_params['callbacks'],
          verbose = model_params['verbose'],
          validation_split = model_params['validation_split'],
          validation_data = model_params['validation_data'],
          shuffle = model_params['shuffle'],
          initial_epoch = model_params['initial_epoch'],
          steps_per_epoch = model_params['steps_per_epoch'],
          validation_steps = model_params['validation_steps']
            )
# Out:
# Train on 9747 samples, validate on 38993 samples
# Epoch 1/10
# 9747/9747 [==============================] - 319s 33ms/step - loss: 3.0365 - val_loss: 3.0313
#
# Epoch 00001: loss improved from inf to 3.03650, saving model to Weights-GRU-improvement-001-3.03650-bigger.hdf5
# Epoch 2/10
# 9747/9747 [==============================] - 368s 38ms/step - loss: 3.0138 - val_loss: 3.0377
#
# Epoch 00002: loss improved from 3.03650 to 3.01379, saving model to Weights-GRU-improvement-002-3.01379-bigger.hdf5
# Epoch 3/10
# 9747/9747 [==============================] - 357s 37ms/step - loss: 3.0076 - val_loss: 3.0197
#
# Epoch 00003: loss improved from 3.01379 to 3.00762, saving model to Weights-GRU-improvement-003-3.00762-bigger.hdf5
# Epoch 4/10
# 9747/9747 [==============================] - 292s 30ms/step - loss: 3.0085 - val_loss: 3.0307
#
# Epoch 00004: loss did not improve from 3.00762
# Epoch 5/10
# 9747/9747 [==============================] - 289s 30ms/step - loss: 2.9791 - val_loss: 3.0069
#
# Epoch 00005: loss improved from 3.00762 to 2.97906, saving model to Weights-GRU-improvement-005-2.97906-bigger.hdf5
# Epoch 6/10
# 9747/9747 [==============================] - 292s 30ms/step - loss: 2.8858 - val_loss: 2.9646
#
# Epoch 00006: loss improved from 2.97906 to 2.88582, saving model to Weights-GRU-improvement-006-2.88582-bigger.hdf5
# Epoch 7/10
# 9747/9747 [==============================] - 290s 30ms/step - loss: 2.7587 - val_loss: 2.9652
#
# Epoch 00007: loss improved from 2.88582 to 2.75866, saving model to Weights-GRU-improvement-007-2.75866-bigger.hdf5
# Epoch 8/10
# 9747/9747 [==============================] - 290s 30ms/step - loss: 2.6886 - val_loss: 2.9664
#
# Epoch 00008: loss improved from 2.75866 to 2.68864, saving model to Weights-GRU-improvement-008-2.68864-bigger.hdf5
# Epoch 9/10
# 9747/9747 [==============================] - 290s 30ms/step - loss: 2.6383 - val_loss: 3.0022
#
# Epoch 00009: loss improved from 2.68864 to 2.63828, saving model to Weights-GRU-improvement-009-2.63828-bigger.hdf5
# Epoch 10/10
# 9747/9747 [==============================] - 289s 30ms/step - loss: 2.5842 - val_loss: 3.0293
#
# Epoch 00010: loss improved from 2.63828 to 2.58422, saving model to Weights-GRU-improvement-010-2.58422-bigger.hdf5

# %%
# Carrega os arquivos
wights_file = 'Weights-GRU-improvement-010-2.58422-bigger.hdf5' # weights file path
model.load_weights(wights_file)
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam')

# %%
# Inicia de maneira randomica
start = np.random.randint(0, len(data_X)-1)
pattern = data_X[start]
print('Seed : ')
print("\"",''.join([int_chars[value] for value in pattern]), "\"\n")
generated_characters = 300
for i in range(generated_characters):
    x = np.reshape(pattern, ( 1, len(pattern), 1))
    x = x / float(n_vocab)
    prediction = model.predict(x,verbose = 0)
    index = np.argmax(prediction)
    result = int_chars[index]
    sys.stdout.write(result)

    pattern.append(index)
    pattern = pattern[1:len(pattern)]
# Out:
# Seed :
# " ão de acontecer
#
# eu acho tão bonito isso
# de ser abstrato, baby
# a beleza é mesmo tão fugaz
#
# é uma ide "
#
#  me de por se
# mer qo
# éevo me so ne sos q qee ce pe ah mos  da mo so qo de sev a mam a vam a d nã me por de se qe ae ao aa ao me so de
# a memaa da aa damaa d dae aee v ce re cara ma dam re dar ée ber de aar de daara
# ear aa dar aeaaaa
# aaaaa mara ra ve êe bee de daaaa a raraa me der me dar baa aera
